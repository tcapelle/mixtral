# %%
import pandas as pd
from tqdm.auto import tqdm
from transformers import AutoModelForCausalLM

# %%
mistral = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-7B-v0.1")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# let's check a model diff

# %%
model_id = "HuggingFaceH4/zephyr-7b-beta"

# %%
model = AutoModelForCausalLM.from_pretrained(model_id)
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
model
# Out:
# MistralForCausalLM(
#   (model): MistralModel(
#     (embed_tokens): Embedding(32000, 4096, padding_idx=2)
#     (layers): ModuleList(
#       (0-31): 32 x MistralDecoderLayer(
#         (self_attn): MistralAttention(
#           (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): MistralRotaryEmbedding()
#         )
#         (mlp): MistralMLP(
#           (gate_proj): Linear(in_features=4096, out_features=14336, bias=False)
#           (up_proj): Linear(in_features=4096, out_features=14336, bias=False)
#           (down_proj): Linear(in_features=14336, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): MistralRMSNorm()
#         (post_attention_layernorm): MistralRMSNorm()
#       )
#     )
#     (norm): MistralRMSNorm()
#   )
#   (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
# )

# %%
def check_tensor_dims(t1, t2):
    dim_where_not_equal = []
    for s1, s2 in zip(t1.shape, t2.shape):
        dim_where_not_equal.append(s1 != s2)
    return dim_where_not_equal

# %%
def _compute_diff(model, ref_model):
    total_params = sum([p.numel() for p in model.parameters()])
    total_layers = sum([1 for p in model.parameters()])
    diffs = {}
    pbar = tqdm(zip(model.state_dict().items(), ref_model.state_dict().items()), total=total_layers)
    for (k_base, p_base), (k_ft, p_ft) in pbar:
        assert k_base == k_ft,"Models don't match, compare to the same model" 
        dim_where_not_equal = check_tensor_dims(p_base, p_ft)
        if sum(dim_where_not_equal):
            print(f"Warning: {k_base} has shape: {p_base.shape} != {p_ft.shape}")
            # we only allow diverging dims on the first and last layers (embedding and head)
            if dim_where_not_equal[0]:
                min_dim = min(p_base.shape[0], p_ft.shape[0])
                p_base = p_base[:min_dim]
                p_ft = p_ft[:min_dim]
        
        _diff = (p_base - p_ft).abs()
        diffs[k_base] = {
            "abs":    _diff.sum().item(), 
            "mean":   _diff.mean().item(),
            # "median": _diff.median().item()
        }
    return diffs

# %%
diffs = _compute_diff(model, mistral)
# Out:
#   0%|          | 0/291 [00:00<?, ?it/s]

# %%
def aggregate_layer_results(data, levels=3):
    # Initialize a dictionary to hold the aggregated results
    aggregated_results = {}

    # Iterate through each key-value pair in the input data
    for key, value in data.items():
        # Identify and extract the layer name
        layer_name_parts = key.split('.')
        layer_name = ".".join(layer_name_parts[:levels])
        
        # Initialize the layer in the aggregated results if not present
        if layer_name not in aggregated_results:
            aggregated_results[layer_name] = {'abs': 0, 'mean': 0, 'count': 0}

        # Aggregate the results
        aggregated_results[layer_name]['abs'] += value['abs']
        aggregated_results[layer_name]['mean'] += value['mean']
        aggregated_results[layer_name]['count'] += 1

    # Calculate the average of the means for each layer
    for layer, stats in aggregated_results.items():
        stats['mean'] /= stats['count']
        del stats['count']  # Remove count as it's no longer needed

    return aggregated_results

# %%
diffs = _compute_diff(model, mistral)
layer_results = aggregate_layer_results(diffs, levels=3)
# Out:
#   0%|          | 0/291 [00:00<?, ?it/s]

# %%
def to_df(data):
    df = pd.DataFrame.from_dict(data, orient='index')
    def apply_color_scale(df):
        return df.style.background_gradient(cmap='Reds', subset=["abs"],  axis=0)\
                       .background_gradient(cmap='Reds', subset=["mean"], axis=0)
    # Apply the color scale to the DataFrame
    styled_df = apply_color_scale(df)
    return styled_df

# %%
df = to_df(layer_results)
df
# Out:
# <style type="text/css">
# #T_38feb_row0_col0 {
#   background-color: #c1161b;
#   color: #f1f1f1;
# }
# #T_38feb_row0_col1, #T_38feb_row1_col0 {
#   background-color: #860811;
#   color: #f1f1f1;
# }
# #T_38feb_row1_col1 {
#   background-color: #ea362a;
#   color: #f1f1f1;
# }
# #T_38feb_row2_col0, #T_38feb_row34_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_38feb_row2_col1 {
#   background-color: #e43027;
#   color: #f1f1f1;
# }
# #T_38feb_row3_col0 {
#   background-color: #a30f15;
#   color: #f1f1f1;
# }
# #T_38feb_row3_col1, #T_38feb_row30_col1 {
#   background-color: #fb6e4e;
#   color: #f1f1f1;
# }
# #T_38feb_row4_col0, #T_38feb_row17_col0 {
#   background-color: #980c13;
#   color: #f1f1f1;
# }
# #T_38feb_row4_col1, #T_38feb_row17_col1 {
#   background-color: #fa6849;
#   color: #f1f1f1;
# }
# #T_38feb_row5_col0 {
#   background-color: #af1117;
#   color: #f1f1f1;
# }
# #T_38feb_row5_col1 {
#   background-color: #fb7656;
#   color: #f1f1f1;
# }
# #T_38feb_row6_col0 {
#   background-color: #aa1016;
#   color: #f1f1f1;
# }
# #T_38feb_row6_col1 {
#   background-color: #fb7252;
#   color: #f1f1f1;
# }
# #T_38feb_row7_col0 {
#   background-color: #b51318;
#   color: #f1f1f1;
# }
# #T_38feb_row7_col1 {
#   background-color: #fb7a5a;
#   color: #f1f1f1;
# }
# #T_38feb_row8_col0, #T_38feb_row15_col0 {
#   background-color: #b01217;
#   color: #f1f1f1;
# }
# #T_38feb_row8_col1, #T_38feb_row15_col1, #T_38feb_row31_col1, #T_38feb_row32_col1 {
#   background-color: #fb7757;
#   color: #f1f1f1;
# }
# #T_38feb_row9_col0 {
#   background-color: #b61319;
#   color: #f1f1f1;
# }
# #T_38feb_row9_col1 {
#   background-color: #fb7d5d;
#   color: #f1f1f1;
# }
# #T_38feb_row10_col0 {
#   background-color: #b91419;
#   color: #f1f1f1;
# }
# #T_38feb_row10_col1 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# #T_38feb_row11_col0 {
#   background-color: #ca181d;
#   color: #f1f1f1;
# }
# #T_38feb_row11_col1, #T_38feb_row13_col1 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_38feb_row12_col0 {
#   background-color: #c9181d;
#   color: #f1f1f1;
# }
# #T_38feb_row12_col1, #T_38feb_row14_col1 {
#   background-color: #fc8161;
#   color: #f1f1f1;
# }
# #T_38feb_row13_col0 {
#   background-color: #cc191e;
#   color: #f1f1f1;
# }
# #T_38feb_row14_col0 {
#   background-color: #c7171c;
#   color: #f1f1f1;
# }
# #T_38feb_row16_col0 {
#   background-color: #9c0d14;
#   color: #f1f1f1;
# }
# #T_38feb_row16_col1 {
#   background-color: #fb6b4b;
#   color: #f1f1f1;
# }
# #T_38feb_row18_col0 {
#   background-color: #960b13;
#   color: #f1f1f1;
# }
# #T_38feb_row18_col1 {
#   background-color: #fb7151;
#   color: #f1f1f1;
# }
# #T_38feb_row19_col0 {
#   background-color: #800610;
#   color: #f1f1f1;
# }
# #T_38feb_row19_col1, #T_38feb_row25_col1 {
#   background-color: #fa6547;
#   color: #f1f1f1;
# }
# #T_38feb_row20_col0 {
#   background-color: #7c0510;
#   color: #f1f1f1;
# }
# #T_38feb_row20_col1 {
#   background-color: #f85f43;
#   color: #f1f1f1;
# }
# #T_38feb_row21_col0, #T_38feb_row23_col0 {
#   background-color: #73030f;
#   color: #f1f1f1;
# }
# #T_38feb_row21_col1, #T_38feb_row23_col1 {
#   background-color: #f75b40;
#   color: #f1f1f1;
# }
# #T_38feb_row22_col0 {
#   background-color: #75030f;
#   color: #f1f1f1;
# }
# #T_38feb_row22_col1 {
#   background-color: #f7593f;
#   color: #f1f1f1;
# }
# #T_38feb_row24_col0 {
#   background-color: #6f020e;
#   color: #f1f1f1;
# }
# #T_38feb_row24_col1 {
#   background-color: #f6583e;
#   color: #f1f1f1;
# }
# #T_38feb_row25_col0 {
#   background-color: #820711;
#   color: #f1f1f1;
# }
# #T_38feb_row26_col0 {
#   background-color: #8a0812;
#   color: #f1f1f1;
# }
# #T_38feb_row26_col1, #T_38feb_row29_col1 {
#   background-color: #fb6d4d;
#   color: #f1f1f1;
# }
# #T_38feb_row27_col0 {
#   background-color: #840711;
#   color: #f1f1f1;
# }
# #T_38feb_row27_col1 {
#   background-color: #fb6c4c;
#   color: #f1f1f1;
# }
# #T_38feb_row28_col0 {
#   background-color: #900a12;
#   color: #f1f1f1;
# }
# #T_38feb_row28_col1 {
#   background-color: #fb7353;
#   color: #f1f1f1;
# }
# #T_38feb_row29_col0 {
#   background-color: #920a13;
#   color: #f1f1f1;
# }
# #T_38feb_row30_col0 {
#   background-color: #940b13;
#   color: #f1f1f1;
# }
# #T_38feb_row31_col0 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
# }
# #T_38feb_row32_col0 {
#   background-color: #a60f15;
#   color: #f1f1f1;
# }
# #T_38feb_row33_col0, #T_38feb_row33_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_38feb_row34_col0 {
#   background-color: #b11218;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_38feb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38feb_level0_col0" class="col_heading level0 col0" >abs</th>
#       <th id="T_38feb_level0_col1" class="col_heading level0 col1" >mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38feb_level0_row0" class="row_heading level0 row0" >model.embed_tokens.weight</th>
#       <td id="T_38feb_row0_col0" class="data row0 col0" >18778.666016</td>
#       <td id="T_38feb_row0_col1" class="data row0 col1" >0.000143</td>
#     </tr>
#     <tr>
#       <th id="T_38feb_level0_row1" class="row_heading level0 row1" >model.layers.0</th>
#       <td id="T_38feb_row1_col0" class="data row1 col0" >22515.555466</td>
#       <td id="T_38feb_row1_col1" class="data row1 col1" >0.000098</td>
#     </tr>
#     <tr>
#       <th id="T_38feb_level0_row2" class="row_heading level0 row2" >model.layers.1</th>
#       <td id="T_38feb_row2_col0" class="data row2 col0" >24025.562738</td>
#       <td id="T_38feb_row2_col1" class="data row2 col1" >0.000101</td>
#     </tr>
#     <tr>
#       <th id="T_38feb_level0_row3" class="row_heading level0 row3" >model.layers.2</th>
#       <td id="T_38feb_row3_col0" class="data row3 col0" >21089.673368</td>
#       <td id="T_38feb_row3_col1" class="data row3 col1" >0.000074</td>
#     </tr>
#     <tr>
#       <th id="T_38feb_level0_row4" class="row_heading level0 row4" >model.layers.3</th>
#       <td id="T_38feb_row4_col0" class="data row4 col0" >21632.520883</td>
#       <td id="T_38feb_row4_col1" class="data row4 col1" >0.000078</td>
#     </tr>
#     <tr>
#       <th id="T_38feb_level0_row5" class="row_heading level0 row5" >model.layers.4</th>
#       <td id="T_38feb_row5_col0" class="data row5 col0" >20266.105537</td>
#       <td id="T_38feb_row5_col1" class="data row5 col1" >0.000071</td>
#     </tr>
#     <tr>
#       <th id="T_38feb_level0_row6" class="row_heading level0 row6" >model.layers.5</th>
#       <td id="T_38feb_row6_col0" class="data row6 col0" >20565.547354</td>
#       <td id="T_38feb_row6_col1" class="data row6 col1" >0.000073</td>
#     </tr>
#     <tr>
#       <th id="T_38feb_level0_row7" class="row_heading level0 row7" >model.layers.6</th>
#       <td id="T_38feb_row7_col0" class="data row7 col0" >19795.855812</td>
#       <td id="T_38feb_row7_col1" class="data row7 col1" >0.000069</td>
#     </tr>
#     <tr>
#       <th id="T_38feb_level0_row8" class="row_heading level0 row8" >model.layers.7</th>
#       <td id="T_38feb_row8_col0" class="data row8 col0" >20123.770569</td>
#       <td id="T_38feb_row8_col1" class="data row8 col1" >0.000070</td>
#     </tr>
#     <tr>
#       <th id="T_38feb_level0_row9" class="row_heading level0 row9" >model.layers.8</th>
#       <td id="T_38feb_row9_col0" class="data row9 col0" >19646.641113</td>
#       <td id="T_38feb_row9_col1" class="data row9 col1" >0.000067</td>
#     </tr>
#     <tr>
#       <th id="T_38feb_level0_row10" class="row_heading level0 row10" >model.layers.9</th>
#       <td id="T_38feb_row10_col0" class="data row10 col0" >19404.921509</td>
#       <td id="T_38feb_row10_col1" class="data row10 col1" >0.000068</td>
#     </tr>
#     <tr>
#       <th id="T_38feb_level0_row11" class="row_heading level0 row11" >model.layers.10</th>
#       <td id="T_38feb_row11_col0" class="data row11 col0" >18106.846710</td>
#       <td id="T_38feb_row11_col1" class="data row11 col1" >0.000065</td>
#     </tr>
#     <tr>
#       <th id="T_38feb_level0_row12" class="row_heading level0 row12" >model.layers.11</th>
#       <td id="T_38feb_row12_col0" class="data row12 col0" >18117.051697</td>
#       <td id="T_38feb_row12_col1" class="data row12 col1" >0.000065</td>
#     </tr>
#     <tr>
#       <th id="T_38feb_level0_row13" class="row_heading level0 row13" >model.layers.12</th>
#       <td id="T_38feb_row13_col0" class="data row13 col0" >17846.156860</td>
#       <td id="T_38feb_row13_col1" class="data row1

# %%
def compute_diff(model_id, ref_model_id, levels=3):
    model = AutoModelForCausalLM.from_pretrained(model_id)
    ref_model = AutoModelForCausalLM.from_pretrained(ref_model_id)
    diffs =  _compute_diff(model, ref_model)
    layer_results = aggregate_layer_results(diffs, levels=levels)
    return to_df(layer_results)

# %%
res_df = compute_diff("mistralai/Mistral-7B-Instruct-v0.1", "mistralai/Mistral-7B-v0.1")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/291 [00:00<?, ?it/s]

# %%
res_df
# Out:
# <style type="text/css">
# #T_4422a_row0_col0 {
#   background-color: #f75b40;
#   color: #f1f1f1;
# }
# #T_4422a_row0_col1, #T_4422a_row33_col0, #T_4422a_row34_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_4422a_row1_col0 {
#   background-color: #9a0c14;
#   color: #f1f1f1;
# }
# #T_4422a_row1_col1, #T_4422a_row24_col1 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_4422a_row2_col0, #T_4422a_row31_col0 {
#   background-color: #800610;
#   color: #f1f1f1;
# }
# #T_4422a_row2_col1, #T_4422a_row3_col1, #T_4422a_row6_col1, #T_4422a_row14_col1, #T_4422a_row17_col1, #T_4422a_row26_col1 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_4422a_row3_col0, #T_4422a_row4_col0, #T_4422a_row29_col0 {
#   background-color: #6d010e;
#   color: #f1f1f1;
# }
# #T_4422a_row4_col1, #T_4422a_row5_col1, #T_4422a_row7_col1, #T_4422a_row8_col1, #T_4422a_row10_col1, #T_4422a_row11_col1, #T_4422a_row12_col1, #T_4422a_row13_col1, #T_4422a_row15_col1, #T_4422a_row16_col1, #T_4422a_row19_col1, #T_4422a_row25_col1 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_4422a_row5_col0 {
#   background-color: #71020e;
#   color: #f1f1f1;
# }
# #T_4422a_row6_col0, #T_4422a_row21_col0 {
#   background-color: #73030f;
#   color: #f1f1f1;
# }
# #T_4422a_row7_col0, #T_4422a_row8_col0, #T_4422a_row16_col0, #T_4422a_row17_col0, #T_4422a_row18_col0 {
#   background-color: #75030f;
#   color: #f1f1f1;
# }
# #T_4422a_row9_col0, #T_4422a_row10_col0, #T_4422a_row12_col0, #T_4422a_row13_col0, #T_4422a_row14_col0, #T_4422a_row15_col0, #T_4422a_row19_col0, #T_4422a_row20_col0, #T_4422a_row30_col0 {
#   background-color: #77040f;
#   color: #f1f1f1;
# }
# #T_4422a_row9_col1, #T_4422a_row20_col1 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_4422a_row11_col0 {
#   background-color: #79040f;
#   color: #f1f1f1;
# }
# #T_4422a_row18_col1, #T_4422a_row23_col1 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_4422a_row21_col1 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_4422a_row22_col0 {
#   background-color: #6f020e;
#   color: #f1f1f1;
# }
# #T_4422a_row22_col1 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_4422a_row23_col0, #T_4422a_row24_col0 {
#   background-color: #69000d;
#   color: #f1f1f1;
# }
# #T_4422a_row25_col0, #T_4422a_row26_col0, #T_4422a_row27_col0, #T_4422a_row33_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_4422a_row27_col1 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_4422a_row28_col0 {
#   background-color: #6b010e;
#   color: #f1f1f1;
# }
# #T_4422a_row28_col1 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_4422a_row29_col1 {
#   background-color: #ffefe8;
#   color: #000000;
# }
# #T_4422a_row30_col1 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_4422a_row31_col1 {
#   background-color: #feeae1;
#   color: #000000;
# }
# #T_4422a_row32_col0 {
#   background-color: #a10e15;
#   color: #f1f1f1;
# }
# #T_4422a_row32_col1 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_4422a_row34_col0 {
#   background-color: #f85f43;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4422a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4422a_level0_col0" class="col_heading level0 col0" >abs</th>
#       <th id="T_4422a_level0_col1" class="col_heading level0 col1" >mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4422a_level0_row0" class="row_heading level0 row0" >model.embed_tokens.weight</th>
#       <td id="T_4422a_row0_col0" class="data row0 col0" >57131.996094</td>
#       <td id="T_4422a_row0_col1" class="data row0 col1" >0.000436</td>
#     </tr>
#     <tr>
#       <th id="T_4422a_level0_row1" class="row_heading level0 row1" >model.layers.0</th>
#       <td id="T_4422a_row1_col0" class="data row1 col0" >94654.652822</td>
#       <td id="T_4422a_row1_col1" class="data row1 col1" >0.000623</td>
#     </tr>
#     <tr>
#       <th id="T_4422a_level0_row2" class="row_heading level0 row2" >model.layers.1</th>
#       <td id="T_4422a_row2_col0" class="data row2 col0" >100114.943449</td>
#       <td id="T_4422a_row2_col1" class="data row2 col1" >0.000876</td>
#     </tr>
#     <tr>
#       <th id="T_4422a_level0_row3" class="row_heading level0 row3" >model.layers.2</th>
#       <td id="T_4422a_row3_col0" class="data row3 col0" >104377.885955</td>
#       <td id="T_4422a_row3_col1" class="data row3 col1" >0.000889</td>
#     </tr>
#     <tr>
#       <th id="T_4422a_level0_row4" class="row_heading level0 row4" >model.layers.3</th>
#       <td id="T_4422a_row4_col0" class="data row4 col0" >104298.319109</td>
#       <td id="T_4422a_row4_col1" class="data row4 col1" >0.000785</td>
#     </tr>
#     <tr>
#       <th id="T_4422a_level0_row5" class="row_heading level0 row5" >model.layers.4</th>
#       <td id="T_4422a_row5_col0" class="data row5 col0" >103622.169692</td>
#       <td id="T_4422a_row5_col1" class="data row5 col1" >0.000808</td>
#     </tr>
#     <tr>
#       <th id="T_4422a_level0_row6" class="row_heading level0 row6" >model.layers.5</th>
#       <td id="T_4422a_row6_col0" class="data row6 col0" >103278.184989</td>
#       <td id="T_4422a_row6_col1" class="data row6 col1" >0.000899</td>
#     </tr>
#     <tr>
#       <th id="T_4422a_level0_row7" class="row_heading level0 row7" >model.layers.6</th>
#       <td id="T_4422a_row7_col0" class="data row7 col0" >102811.395339</td>
#       <td id="T_4422a_row7_col1" class="data row7 col1" >0.000786</td>
#     </tr>
#     <tr>
#       <th id="T_4422a_level0_row8" class="row_heading level0 row8" >model.layers.7</th>
#       <td id="T_4422a_row8_col0" class="data row8 col0" >102527.069824</td>
#       <td id="T_4422a_row8_col1" class="data row8 col1" >0.000783</td>
#     </tr>
#     <tr>
#       <th id="T_4422a_level0_row9" class="row_heading level0 row9" >model.layers.8</th>
#       <td id="T_4422a_row9_col0" class="data row9 col0" >102125.578369</td>
#       <td id="T_4422a_row9_col1" class="data row9 col1" >0.000770</td>
#     </tr>
#     <tr>
#       <th id="T_4422a_level0_row10" class="row_heading level0 row10" >model.layers.9</th>
#       <td id="T_4422a_row10_col0" class="data row10 col0" >102295.751465</td>
#       <td id="T_4422a_row10_col1" class="data row10 col1" >0.000838</td>
#     </tr>
#     <tr>
#       <th id="T_4422a_level0_row11" class="row_heading level0 row11" >model.layers.10</th>
#       <td id="T_4422a_row11_col0" class="data row11 col0" >102029.972290</td>
#       <td id="T_4422a_row11_col1" class="data row11 col1" >0.000795</td>
#     </tr>
#     <tr>
#       <th id="T_4422a_level0_row12" class="row_heading level0 row12" >model.layers.11</th>
#       <td id="T_4422a_row12_col0" class="data row12 col0" >102282.080444</td>
#       <td id="T_4422a_row12_col1" class="data row12 col1" >0.000838</td>
#     </tr>
#     <tr>
#       <th id="T_4422a_level0_row13" class="row_heading level0 row13" >model.layers.12</th>
#       <td id="T_4422a_row13_col0" class="data row13 col0" >102436.636963</td>
#       <td id="T_4422a_row13_col1" class="data row13 col1" >0.000828</td>
#     </tr>
#     <tr>
#       <th id="T_4422a_level0_row14" class="row_heading level0 row14" >model.layers.13</th>
#       <td id="T_4422a_row14_col0" class="data row14 col0" >102320.225342</td>
#       <td id="T_4422a_row14_col1" class="data row14 col1" >0.000857</td>
#     </tr>
#     <tr>
#       <th id="T_4422a_level0_row15" class="row_heading level0 row15" >model.layers.14</th>
#       <td id="T_4422a_row15_col0" class="data row15 col0" >102303.009399</td>
#       <td id="T_4422a_row15_col1" class="data row15 col1" >0.000782</td>
#     </tr>
#     <tr>
#       <th id="T_4422a_level0_row16" class="row_heading level0 row16" >model.layers.15</th>
#       <td id="T_4422a_row16_col0" class="data row16 col0" >102738.632812</td>
#       <td id="T_4422a_row16_col1" class="data row16 col1" >0.000834</td>
#     </tr>
#     <tr>
#       <th id="T_4422a_level0_row17" class="row_heading level0 row17" >model.layers.16</th>
#       <td id="T_4422a_row17_col0" class="data row17 col0" >102578.408203</td>
#       <td id="T_4422a_row17_col1" class="data row17 col1" >0.000900</td>
#     </tr>
#     <tr>
#       <th id="T_4422a_level0_row18" class="row_heading level0 row18" >model.layers.17</th>
#       <td id="T_4422a_row18_col0" class="data row18 col0" >10

# %%
tek_model = "teknium/OpenHermes-2.5-Mistral-7B"

res_df = compute_diff("teknium/OpenHermes-2.5-Mistral-7B", "mistralai/Mistral-7B-v0.1")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/291 [00:00<?, ?it/s]
# Warning: model.embed_tokens.weight has shape: torch.Size([32002, 4096]) != torch.Size([32000, 4096])
# Warning: lm_head.weight has shape: torch.Size([32002, 4096]) != torch.Size([32000, 4096])

# %%
res_df
# Out:
# <style type="text/css">
# #T_8e7e2_row0_col0 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_8e7e2_row0_col1 {
#   background-color: #f14130;
#   color: #f1f1f1;
# }
# #T_8e7e2_row1_col0 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# #T_8e7e2_row1_col1 {
#   background-color: #fc9d7f;
#   color: #000000;
# }
# #T_8e7e2_row2_col0 {
#   background-color: #f34935;
#   color: #f1f1f1;
# }
# #T_8e7e2_row2_col1 {
#   background-color: #fb6e4e;
#   color: #f1f1f1;
# }
# #T_8e7e2_row3_col0, #T_8e7e2_row26_col1 {
#   background-color: #da2723;
#   color: #f1f1f1;
# }
# #T_8e7e2_row3_col1 {
#   background-color: #e43027;
#   color: #f1f1f1;
# }
# #T_8e7e2_row4_col0 {
#   background-color: #cb181d;
#   color: #f1f1f1;
# }
# #T_8e7e2_row4_col1 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_8e7e2_row5_col0 {
#   background-color: #be151a;
#   color: #f1f1f1;
# }
# #T_8e7e2_row5_col1 {
#   background-color: #cf1c1f;
#   color: #f1f1f1;
# }
# #T_8e7e2_row6_col0 {
#   background-color: #ac1117;
#   color: #f1f1f1;
# }
# #T_8e7e2_row6_col1 {
#   background-color: #b81419;
#   color: #f1f1f1;
# }
# #T_8e7e2_row7_col0 {
#   background-color: #a50f15;
#   color: #f1f1f1;
# }
# #T_8e7e2_row7_col1 {
#   background-color: #b71319;
#   color: #f1f1f1;
# }
# #T_8e7e2_row8_col0, #T_8e7e2_row10_col1 {
#   background-color: #920a13;
#   color: #f1f1f1;
# }
# #T_8e7e2_row8_col1, #T_8e7e2_row21_col1 {
#   background-color: #a81016;
#   color: #f1f1f1;
# }
# #T_8e7e2_row9_col0 {
#   background-color: #880811;
#   color: #f1f1f1;
# }
# #T_8e7e2_row9_col1 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
# }
# #T_8e7e2_row10_col0 {
#   background-color: #800610;
#   color: #f1f1f1;
# }
# #T_8e7e2_row11_col0, #T_8e7e2_row13_col1 {
#   background-color: #820711;
#   color: #f1f1f1;
# }
# #T_8e7e2_row11_col1 {
#   background-color: #8c0912;
#   color: #f1f1f1;
# }
# #T_8e7e2_row12_col0, #T_8e7e2_row19_col1 {
#   background-color: #7e0610;
#   color: #f1f1f1;
# }
# #T_8e7e2_row12_col1, #T_8e7e2_row20_col0, #T_8e7e2_row34_col1 {
#   background-color: #8a0812;
#   color: #f1f1f1;
# }
# #T_8e7e2_row13_col0, #T_8e7e2_row19_col0 {
#   background-color: #7a0510;
#   color: #f1f1f1;
# }
# #T_8e7e2_row14_col0, #T_8e7e2_row18_col1 {
#   background-color: #73030f;
#   color: #f1f1f1;
# }
# #T_8e7e2_row14_col1 {
#   background-color: #75030f;
#   color: #f1f1f1;
# }
# #T_8e7e2_row15_col0, #T_8e7e2_row15_col1 {
#   background-color: #6f020e;
#   color: #f1f1f1;
# }
# #T_8e7e2_row16_col0, #T_8e7e2_row18_col0 {
#   background-color: #6d010e;
#   color: #f1f1f1;
# }
# #T_8e7e2_row16_col1 {
#   background-color: #71020e;
#   color: #f1f1f1;
# }
# #T_8e7e2_row17_col0, #T_8e7e2_row17_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_8e7e2_row20_col1 {
#   background-color: #940b13;
#   color: #f1f1f1;
# }
# #T_8e7e2_row21_col0 {
#   background-color: #9a0c14;
#   color: #f1f1f1;
# }
# #T_8e7e2_row22_col0 {
#   background-color: #a91016;
#   color: #f1f1f1;
# }
# #T_8e7e2_row22_col1 {
#   background-color: #b51318;
#   color: #f1f1f1;
# }
# #T_8e7e2_row23_col0 {
#   background-color: #b01217;
#   color: #f1f1f1;
# }
# #T_8e7e2_row23_col1 {
#   background-color: #c3161b;
#   color: #f1f1f1;
# }
# #T_8e7e2_row24_col0 {
#   background-color: #b31218;
#   color: #f1f1f1;
# }
# #T_8e7e2_row24_col1, #T_8e7e2_row26_col0 {
#   background-color: #c4161c;
#   color: #f1f1f1;
# }
# #T_8e7e2_row25_col0 {
#   background-color: #bd151a;
#   color: #f1f1f1;
# }
# #T_8e7e2_row25_col1, #T_8e7e2_row31_col0 {
#   background-color: #d11e1f;
#   color: #f1f1f1;
# }
# #T_8e7e2_row27_col0 {
#   background-color: #c8171c;
#   color: #f1f1f1;
# }
# #T_8e7e2_row27_col1, #T_8e7e2_row28_col1 {
#   background-color: #dc2924;
#   color: #f1f1f1;
# }
# #T_8e7e2_row28_col0, #T_8e7e2_row32_col0 {
#   background-color: #ce1a1e;
#   color: #f1f1f1;
# }
# #T_8e7e2_row29_col0 {
#   background-color: #d01d1f;
#   color: #f1f1f1;
# }
# #T_8e7e2_row29_col1 {
#   background-color: #d82422;
#   color: #f1f1f1;
# }
# #T_8e7e2_row30_col0, #T_8e7e2_row32_col1 {
#   background-color: #d32020;
#   color: #f1f1f1;
# }
# #T_8e7e2_row30_col1 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_8e7e2_row31_col1 {
#   background-color: #d52221;
#   color: #f1f1f1;
# }
# #T_8e7e2_row33_col0, #T_8e7e2_row33_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_8e7e2_row34_col0 {
#   background-color: #fb7c5c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8e7e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e7e2_level0_col0" class="col_heading level0 col0" >abs</th>
#       <th id="T_8e7e2_level0_col1" class="col_heading level0 col1" >mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e7e2_level0_row0" class="row_heading level0 row0" >model.embed_tokens.weight</th>
#       <td id="T_8e7e2_row0_col0" class="data row0 col0" >4657.928223</td>
#       <td id="T_8e7e2_row0_col1" class="data row0 col1" >0.000036</td>
#     </tr>
#     <tr>
#       <th id="T_8e7e2_level0_row1" class="row_heading level0 row1" >model.layers.0</th>
#       <td id="T_8e7e2_row1_col0" class="data row1 col0" >6601.050701</td>
#       <td id="T_8e7e2_row1_col1" class="data row1 col1" >0.000020</td>
#     </tr>
#     <tr>
#       <th id="T_8e7e2_level0_row2" class="row_heading level0 row2" >model.layers.1</th>
#       <td id="T_8e7e2_row2_col0" class="data row2 col0" >9378.093040</td>
#       <td id="T_8e7e2_row2_col1" class="data row2 col1" >0.000028</td>
#     </tr>
#     <tr>
#       <th id="T_8e7e2_level0_row3" class="row_heading level0 row3" >model.layers.2</th>
#       <td id="T_8e7e2_row3_col0" class="data row3 col0" >11159.152022</td>
#       <td id="T_8e7e2_row3_col1" class="data row3 col1" >0.000039</td>
#     </tr>
#     <tr>
#       <th id="T_8e7e2_level0_row4" class="row_heading level0 row4" >model.layers.3</th>
#       <td id="T_8e7e2_row4_col0" class="data row4 col0" >11977.889692</td>
#       <td id="T_8e7e2_row4_col1" class="data row4 col1" >0.000041</td>
#     </tr>
#     <tr>
#       <th id="T_8e7e2_level0_row5" class="row_heading level0 row5" >model.layers.4</th>
#       <td id="T_8e7e2_row5_col0" class="data row5 col0" >12613.707894</td>
#       <td id="T_8e7e2_row5_col1" class="data row5 col1" >0.000043</td>
#     </tr>
#     <tr>
#       <th id="T_8e7e2_level0_row6" class="row_heading level0 row6" >model.layers.5</th>
#       <td id="T_8e7e2_row6_col0" class="data row6 col0" >13588.014727</td>
#       <td id="T_8e7e2_row6_col1" class="data row6 col1" >0.000047</td>
#     </tr>
#     <tr>
#       <th id="T_8e7e2_level0_row7" class="row_heading level0 row7" >model.layers.6</th>
#       <td id="T_8e7e2_row7_col0" class="data row7 col0" >13932.616326</td>
#       <td id="T_8e7e2_row7_col1" class="data row7 col1" >0.000048</td>
#     </tr>
#     <tr>
#       <th id="T_8e7e2_level0_row8" class="row_heading level0 row8" >model.layers.7</th>
#       <td id="T_8e7e2_row8_col0" class="data row8 col0" >14594.487610</td>
#       <td id="T_8e7e2_row8_col1" class="data row8 col1" >0.000050</td>
#     </tr>
#     <tr>
#       <th id="T_8e7e2_level0_row9" class="row_heading level0 row9" >model.layers.8</th>
#       <td id="T_8e7e2_row9_col0" class="data row9 col0" >14904.710556</td>
#       <td id="T_8e7e2_row9_col1" class="data row9 col1" >0.000052</td>
#     </tr>
#     <tr>
#       <th id="T_8e7e2_level0_row10" class="row_heading level0 row10" >model.layers.9</th>
#       <td id="T_8e7e2_row10_col0" class="data row10 col0" >15148.738586</td>
#       <td id="T_8e7e2_row10_col1" class="data row10 col1" >0.000053</td>
#     </tr>
#     <tr>
#       <th id="T_8e7e2_level0_row11" class="row_heading level0 row11" >model.layers.10</th>
#       <td id="T_8e7e2_row11_col0" class="data row11 col0" >15093.761749</td>
#       <td id="T_8e7e2_row11_col1" class="data row11 col1" >0.000054</td>
#     </tr>
#     <tr>
#       <th id="T_8e7e2_level0_row12" class="row_heading level0 row12" >model.layers.11</th>
#       <td id="T_8e7e2_row12_col0" class="data row12 col0" >15176.575073</td>
#       <td id="T_8e7e2_row12_col1" class="data row12 col1" >0.000054</td>
#     </tr>
#     <tr>
#       <th id="T_8e7e2_level0_row13" class="row_heading level0 row13" >model.layers.12</th>
#       <td id="T_8e7e2_row13_col0" class="data row13 col0" >15350.806030</td>
#       <td id="T_8e7e2_row13_col1" class="data row13 col1" >0.000055</td>
#     </tr>
#     <tr>
#       <th id="T_8e7e2_level0_row14" class="row_heading level0

# %%
model_id = "Open-Orca/Mistral-7B-OpenOrca"
res_df = compute_diff(model_id, "mistralai/Mistral-7B-v0.1")
res_df
# Out:
# config.json:   0%|          | 0.00/623 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.94G [00:00<?, ?B/s]
